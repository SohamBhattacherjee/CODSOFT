# %% [markdown]
# # IRIS FLOWER CLASSIFICATION

# %% [markdown]
# # Project Overview:
#
#  * Within the Iris flower dataset, three distinct species, namely setosa, versicolor, and virginica, are distinguishable through precise measurements. Imagine possessing a dataset that categorizes Iris flowers by species based on these measurements.
#
#  # Project Objective:
#  * Our goal is to develop a machine learning model capable of learning from these data points and efficiently classifying Iris flowers into their corresponding species.

# %% [markdown]
# ![Image Alt Text](iris.png)

# %%
#import Libaries for Data Exploration and Data Preprocessing:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings   #import warnings to ignore warnings
warnings.filterwarnings("ignore")

# %%
iris = pd.read_csv("D:\DATASET\Iris Flower\IRIS.csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
iris['species'].unique().tolist()
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
sns.countplot(x = iris['species'])
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
#Creating a line plot for understanding the visualization
plt.plot(iris['sepal_length'],iris['petal_length'])
plt.xlabel('Sepal Length (in cm)')
plt.ylabel('Petal Length (in cm)')
plt.title("A Line Plot between Sepal Length vs Petal Length")
plt.grid(True)
plt.show()

# %%
#Creating a line plot for understanding the visualization
plt.plot(iris['sepal_width'],iris['petal_width'])
plt.xlabel('Sepal Width (in cm)')
plt.ylabel('Petal Width (in cm)')
plt.title("A Line Plot between Sepal width vs Petal Width")
plt.grid(True)
plt.show()

# %%
#Creating a line plot for understanding the visualization
iris.hist()
plt.grid(True) #Adding a grid for better redability
plt.show()

# %%
#Create a scatter plot with different point sizes
plt.scatter(iris['sepal_length'],iris['petal_length'])
plt.xlabel('Sepal Length(Cm)')
plt.ylabel('Petal Length(Cm)')
plt.title('Relation between Sepal Length vs Petal Length')
plt.grid(True)
plt.show()

# %%
#Create a scatter plot with different point sizes
plt.scatter(iris['sepal_width'],iris['petal_width'])
plt.xlabel('Sepal Width(Cm)')
plt.ylabel('Petal Width(Cm)')
plt.title('Relation between Sepal Width vs Petal Width')
plt.grid(True)
plt.show()

# %%
species_name = {'Iris-versicolor':0,'Iris-virginica':1,'Iris-setosa':2}
color = [species_name[item] for item in iris['species']]
scatter = plt.scatter(iris['sepal_length'],iris['sepal_width'],c=color)
plt.xlabel('Sepal Length (in cm)')
plt.ylabel('Sepal Width (in cm)')
plt.legend(handles = scatter.legend_elements()[0],labels=species_name)
plt.show()

# %%
species_name = {'Iris-versicolor':0,'Iris-virginica':1,'Iris-setosa':2}
color = [species_name[item] for item in iris['species']]
scatter = plt.scatter(iris['petal_length'],iris['petal_width'],c=color)
plt.xlabel('petal Length (in cm)')
plt.ylabel('petal Width (in cm)')
plt.legend(handles = scatter.legend_elements()[0],labels=species_name)
plt.show()

# %%
#Columns to create boxplots for
columns_to_plot=['sepal_length','sepal_width','petal_length','petal_width']

#Create a list of different colors
colors=['blue','green','red','purple']

#Create subplots
fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(12,8))

#Iterate through columns and create boxplots with different colors
for i,column in enumerate(columns_to_plot):
    sns.boxplot(data=iris[column],ax=axes[i//2, i%2],palette=[colors[i]])
    axes[i//2, i%2].set_title(column)

#Adjust layout
plt.tight_layout()
plt.show()

# %%
#Rug plot
plt.figure(figsize=(8,5))
sns.rugplot(data=iris['sepal_length'],height=0.5)
plt.title("Rug plot of Sepal_length")
plt.xlabel("Sepal length(cm)")
plt.ylabel("Density")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Rug plot
plt.figure(figsize=(8,5))
sns.rugplot(data=iris['sepal_width'],height=0.5)
plt.title("Rug plot of Sepal_width")
plt.xlabel("Sepal width(cm)")
plt.ylabel("Density")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Rug plot
plt.figure(figsize=(8,5))
sns.rugplot(data=iris['petal_length'],height=0.5)
plt.title("Rug plot of Petal_length")
plt.xlabel("Petal length(cm)")
plt.ylabel("Density")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Rug plot
plt.figure(figsize=(8,5))
sns.rugplot(data=iris['petal_width'],height=0.5)
plt.title("Rug plot of Petal_width")
plt.xlabel("Petal_width(cm)")
plt.ylabel("Density")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Pair Plot
sns.set(style="ticks")
sns.pairplot(iris,diag_kind='hist',hue="species",markers=["o","s","D"])
plt.show()

# %%
#Create a Facet grid of pairwise scatterplots
g=sns.PairGrid(iris,hue="species")
g.map_upper(sns.scatterplot)
g.map_diag(sns.histplot,kde_kws={"color":"k"})
g.map_lower(sns.kdeplot)
g.add_legend()
plt.show()

# %%
#Encoding the "species"
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
iris['species'] = encoder.fit_transform(iris['species'])

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
iris['species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: species, dtype: int64

# %%
#Compute the correlation matrix
corr_matrix=iris.corr()
#Create a heatmap
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt=".2f",linewidth=0.5)
plt.title('Correlation Plot')
plt.show()

# %%
x=iris.drop('species',axis=1)
y=iris['species']

# %%
print(x)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)
print(X_train.shape)
print(X_test.shape)
# Out:
# (120, 4)
# (30, 4)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(X_test)
y_pred
# Out:
# array([0, 0, 2, 0, 0, 2, 0, 2, 2, 0, 0, 0, 0, 0, 1, 1, 0, 1, 2, 1, 1, 1,
#        2, 1, 1, 0, 0, 2, 0, 2])

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
accuracy_score(y_pred,y_test)
# Out:
# 1.0

# %%
cm = confusion_matrix(y_pred,y_test)
cm
# Out:
# array([[14,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  0,  8]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
#lets do some predictions
x_new = [[1, 0.5, 2.3, 4]]
prediction = knn.predict(x_new)

if prediction == 0:
    prediction_label = "Iris-setosa"
elif prediction == 1:
    prediction_label = "Iris-versicolor"
else:
    prediction_label = "Iris-virginica"

print("Prediction for values:", x_new[0], "is:", prediction_label)
# Out:
# Prediction for values: [1, 0.5, 2.3, 4] is: Iris-versicolor

# %%
x_new = [[5.9,3.0,5.1,1.8]]
prediction = knn.predict(x_new)

if prediction == 0:
    prediction_label = "Iris-setosa"
elif prediction == 1:
    prediction_label = "Iris-versicolor"
else:
    prediction_label = "Iris-virginica"

print("Prediction for values:", x_new[0], "is:", prediction_label)
# Out:
# Prediction for values: [5.9, 3.0, 5.1, 1.8] is: Iris-virginica
